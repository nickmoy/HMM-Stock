# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
# %run finance_data.ipynb

# %%
# https://users.cs.duke.edu/~bdhingra/papers/stock_hmm.pdf
# 0) Initialize A and Pi using uniform distributions and B using k-means clustering
# 1) Train HMM using Baum-Welch to iterate on Pi, A, B
# 2) Predict observation O_(d+1) for (d+1)-th day based on O_1, ..., O_d
#    using forwards-backwards algorithm (1st half of Baum-Welch)
#    - Calculate P(O_1, ..., O_d, O_(d+1) | theta) using alpha_k and beta_k from forwards-backwards
#    - Choose vector for O_(d+1) which maximizes above posterior


# N = number of hidden states
# K = number of observable features (each a continuous Gaussian random variable) (frac change, frac high, frac low)
# M = number of mixture components for each state
# D = number of days used for prediction (latency)
# T = number of observations (days) in dataset
N = 4
K = (50, 10, 10)
M = 5
D = 10

# A = state transition matrix (N x N)
A = np.ones([N, N])/N

# alpha = probability of having seeing observations up to day t and end in state i (N x T)
# beta = probability of having starting at state i at time t and seeing the remaining observations (N x T)

Pi= np.ones(N)/N

# %%
def FracChange(o):
    return np.array([(o[0]-25)/25*0.025, (o[1]-5)/5*0.025, (o[2]-5)/5*0.025])

def index(y):
    return (np.clip(int(y[0]/0.025*25 + 25), 0, 49), np.clip(int(y[1]/0.025*5 + 5), 0, 9), np.clip(int(y[2]/0.025*5 + 5), 0, 9))

def indicatorK(y, k):
    return int(y==k)

def multivariate3_normal(mu, cov, X):
    diff = (X - mu)
    numerator = np.exp(-(1/2) * diff.dot(np.linalg.inv(cov)).dot(diff))
    denominator = np.sqrt((2 * np.pi)**3 * np.abs(np.linalg.det(cov)))
    return numerator/denominator

# %%
# Get stock price data
scraper = Scraper()
scraper.getPrice("AAPL", 150)
O = scraper.preprocess() * 100
T = len(O)

# %%
T
# Out:
# 150

# %%
np.set_printoptions(precision=6, suppress=True)
O
# Out:
# array([[ 0.464335,  0.640915,  1.052492],
#        [ 0.523401,  1.134943,  0.588898],
#        [-1.431143,  0.24145 ,  1.707713],
#        [-0.052975,  0.644535,  0.648949],
#        [ 0.327767,  0.6201  ,  0.141737],
#        [ 0.075315,  0.119617,  1.187312],
#        [ 0.951233,  1.298276,  0.120534],
#        [ 0.053428,  0.333927,  0.819234],
#        [ 0.521376,  1.115292,  0.394433],
#        [ 1.031916,  1.315008,  0.      ],
#        [ 0.675707,  1.59203 ,  0.217522],
#        [ 1.951934,  2.206494,  0.061268],
#        [ 0.093815,  0.51145 ,  2.008358],
#        [ 1.41131 ,  3.257612,  0.246496],
#        [ 0.940095,  2.284454,  2.060378],
#        [ 5.160804,  7.28643 ,  0.452263],
#        [ 0.323986,  2.943192,  0.657063],
#        [-2.678611,  0.049038,  3.275812],
#        [ 0.289033,  1.074798,  0.365801],
#        [-0.177928,  0.517816,  1.400611],
#        [ 0.589971,  1.07854 ,  0.557706],
#        [-0.338363,  0.361225,  1.229995],
#        [-0.657769,  0.876994,  1.968687],
#        [-2.4375  ,  0.357143,  3.066964],
#        [ 0.287496,  1.147709,  0.750979],
#        [-1.343554,  0.339185,  1.726796],
#        [-0.226842,  0.880693,  0.687205],
#        [-2.64895 ,  0.069474,  3.478415],
#        [ 3.980052,  4.22952 ,  0.106898],
#        [-0.604301,  0.171758,  1.00121 ],
#        [ 0.574985,  0.81802 ,  0.207469],
#        [-0.343168,  0.10059 ,  0.467363],
#        [-0.005911,  0.471731,  0.377385],
#        [-0.863228,  0.957186,  0.863228],
#        [ 0.509484,  1.119702,  0.124431],
#        [-0.141946,  0.153745,  0.502622],
#        [-0.677617,  0.03502 ,  1.001814],
#        [-0.157251,  0.279479,  0.721987],
#        [ 1.701766,  1.871961,  0.176018],
#        [-0.170605,  0.835273,  0.247091],
#        [ 0.167101,  0.806175,  0.653709],
#        [ 0.302751,  0.75107 ,  0.989734],
#        [-3.208166,  0.24852 ,  3.507533],
#        [ 1.67881 ,  1.67881 ,  0.358514],
#        [ 0.998031,  1.299177,  0.751456],
#        [-1.053736,  1.218871,  1.167652],
#        [ 0.847135,  0.847135,  0.517043],
#        [ 0.052065,  0.808403,  0.497345],
#        [-0.949249,  0.240228,  1.163423],
#        [-0.011522,  0.508235,  1.235907],
#        [-0.109851,  0.832667,  0.514649],
#        [ 1.023634,  2.781063,  0.035533],
#        [-0.088665,  0.934062,  0.39022 ],
#        [-1.134087,  0.105198,  1.39131 ],
#        [-0.550457,  0.749598,  0.667581],
#        [-0.965068,  0.425764,  1.339781],
#        [-0.280282,  0.18309 ,  1.564971],
#        [-0.346983,  0.55631 ,  1.118086],
#        [-0.793054,  0.158688,  1.476716],
#        [ 1.052067,  1.479969,  0.839361],
#        [-0.587883,  0.301177,  0.856818],
#        [-1.190757,  0.135333,  1.320663],
#        [ 0.195686,  0.532674,  0.820781],
#        [ 0.319183,  0.654257,  0.572378],
#        [-0.277691,  0.32174 ,  1.014563],
#        [-0.894962,  0.565807,  1.153377],
#        [ 0.4364  ,  0.638249,  1.02554 ],
#        [-0.63136 ,  0.113332,  1.554085],
#        [-0.392977,  0.236854,  1.215086],
#        [-0.800377,  0.021202,  0.991198],
#        [ 0.106018,  0.710344,  0.344517],
#        [-0.562358,  0.079239,  1.074523],
#        [-0.629574,  0.230818,  1.049291],
#        [ 1.284089,  1.28946 ,  0.06982 ],
#        [-0.239196,  0.595295,  1.217269],
#        [ 3.336146,  4.159048,  0.333592],
#        [ 1.397305,  1.44611 ,  0.176372],
#        [-1.277815,  0.058819,  1.299175],
#        [-1.523954,  0.445148,  1.822436],
#        [-0.156191,  0.08855 ,  1.275817],
#        [-0.952276,  0.252201,  1.199361],
#        [-0.527658,  0.54684 ,  1.069458],
#        [-0.470768,  0.491263,  0.552645],
#        [ 0.087145,  0.379465,  0.605177]])

# %%
# Initialize B emission probabiliaty matrix using k-means clustering
kmeans = KMeans(n_clusters=M, random_state=0, n_init="auto")
kmeans.fit(O)
clusters = [ [y[1] for y in zip(kmeans.labels_, O) if y[0]==m] for m in range(M)]
mu = np.array([np.mean(cluster, axis=0) for cluster in clusters])
cov = np.array([np.cov(np.array(cluster).T) for cluster in clusters])

# %%
mu
# Out:
# array([[ 0.476105,  1.002937,  0.420412],
#        [-1.923916,  0.38462 ,  2.332715],
#        [ 4.438422,  5.766681,  0.226906],
#        [-0.480697,  0.419372,  1.088508],
#        [ 1.425314,  2.238682,  0.33968 ]])

# %%
B = np.array([\
    [\
        [\
            [\
                (1/(100 * M)) * sum( [multivariate3_normal(mu[m], cov[m], FracChange((frac_change, frac_high, frac_low)))\
                                for m in range(M)] )
                for frac_low in range(10)\
            ] for frac_high in range(10)\
        ] for frac_change in range(50)\
    ] for i in range(N)\
    ])

# %%
O = O / 100
O
# Out:
# array([[ 0.004643,  0.006409,  0.010525],
#        [ 0.005234,  0.011349,  0.005889],
#        [-0.014311,  0.002415,  0.017077],
#        [-0.00053 ,  0.006445,  0.006489],
#        [ 0.003278,  0.006201,  0.001417],
#        [ 0.000753,  0.001196,  0.011873],
#        [ 0.009512,  0.012983,  0.001205],
#        [ 0.000534,  0.003339,  0.008192],
#        [ 0.005214,  0.011153,  0.003944],
#        [ 0.010319,  0.01315 ,  0.      ],
#        [ 0.006757,  0.01592 ,  0.002175],
#        [ 0.019519,  0.022065,  0.000613],
#        [ 0.000938,  0.005114,  0.020084],
#        [ 0.014113,  0.032576,  0.002465],
#        [ 0.009401,  0.022845,  0.020604],
#        [ 0.051608,  0.072864,  0.004523],
#        [ 0.00324 ,  0.029432,  0.006571],
#        [-0.026786,  0.00049 ,  0.032758],
#        [ 0.00289 ,  0.010748,  0.003658],
#        [-0.001779,  0.005178,  0.014006],
#        [ 0.0059  ,  0.010785,  0.005577],
#        [-0.003384,  0.003612,  0.0123  ],
#        [-0.006578,  0.00877 ,  0.019687],
#        [-0.024375,  0.003571,  0.03067 ],
#        [ 0.002875,  0.011477,  0.00751 ],
#        [-0.013436,  0.003392,  0.017268],
#        [-0.002268,  0.008807,  0.006872],
#        [-0.026489,  0.000695,  0.034784],
#        [-0.002484,  0.00876 ,  0.012247],
#        [-0.000766,  0.005405,  0.011362],
#        [-0.008796,  0.003172,  0.014335],
#        [ 0.007077,  0.01625 ,  0.001048],
#        [-0.016509,  0.004321,  0.024288],
#        [ 0.016049,  0.016485,  0.000218],
#        [ 0.003291,  0.00645 ,  0.006835],
#        [ 0.003215,  0.003347,  0.01691 ],
#        [ 0.021159,  0.021655,  0.      ],
#        [ 0.007045,  0.007045,  0.004409],
#        [ 0.019061,  0.01957 ,  0.004858],
#        [ 0.021972,  0.025555,  0.000802],
#        [-0.023868,  0.001391,  0.025351],
#        [-0.002748,  0.004888,  0.010899],
#        [ 0.008274,  0.015887,  0.004066],
#        [-0.000382,  0.010662,  0.002582],
#        [ 0.002022,  0.023975,  0.00544 ],
#        [-0.013784,  0.00713 ,  0.01559 ],
#        [-0.019866,  0.001449,  0.023746],
#        [-0.015166,  0.00478 ,  0.021095],
#        [ 0.015466,  0.026152,  0.003047],
#        [-0.006359,  0.006173,  0.011924],
#        [-0.002328,  0.00936 ,  0.014622],
#        [ 0.027438,  0.061819,  0.002314],
#        [ 0.069713,  0.069765,  0.000103],
#        [-0.019098,  0.002133,  0.024025],
#        [ 0.01047 ,  0.010726,  0.003644],
#        [-0.006082,  0.004242,  0.007666],
#        [-0.00347 ,  0.005563,  0.011181],
#        [-0.007931,  0.001587,  0.014767],
#        [ 0.010521,  0.0148  ,  0.008394],
#        [-0.005879,  0.003012,  0.008568],
#        [-0.011908,  0.001353,  0.013207],
#        [ 0.001957,  0.005327,  0.008208],
#        [ 0.003192,  0.006543,  0.005724],
#        [-0.002777,  0.003217,  0.010146],
#        [-0.00895 ,  0.005658,  0.011534],
#        [ 0.004364,  0.006382,  0.010255],
#        [-0.006314,  0.001133,  0.015541],
#        [-0.00393 ,  0.002369,  0.012151],
#        [-0.008004,  0.000212,  0.009912],
#        [ 0.00106 ,  0.007103,  0.003445],
#        [-0.005624,  0.000792,  0.010745],
#        [-0.006296,  0.002308,  0.010493],
#        [ 0.012841,  0.012895,  0.000698],
#        [-0.002392,  0.005953,  0.012173],
#        [ 0.033361,  0.04159 ,  0.003336],
#        [ 0.013973,  0.014461,  0.001764],
#        [-0.012778,  0.000588,  0.012992],
#        [-0.01524 ,  0.004451,  0.018224],
#        [-0.001562,  0.000885,  0.012758],
#        [-0.009523,  0.002522,  0.011994],
#        [-0.005277,  0.005468,  0.010695],
#        [-0.004708,  0.004913,  0.005526],
#        [ 0.000871,  0.003795,  0.006052]])

# %%
B
# Out:
# array([[[[0.000005, 0.000005, 0.000005, ..., 0.000006, 0.000006,
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000006, 0.000007,
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000007, 0.000007,
#           0.000007],
#          ...,
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000008],
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000009],
#          [0.000006, 0.000006, 0.000007, ..., 0.000008, 0.000009,
#           0.000009]],
#
#         [[0.000005, 0.000005, 0.000005, ..., 0.000006, 0.000006,
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000006, 0.000007,
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000007, 0.000007,
#           0.000007],
#          ...,
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000008],
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000009],
#          [0.000006, 0.000006, 0.000007, ..., 0.000008, 0.000009,
#           0.000009]],
#
#         [[0.000005, 0.000005, 0.000005, ..., 0.000006, 0.000006,
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000006, 0.000007,
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000007, 0.000007,
#           0.000007],
#          ...,
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000008],
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000009],
#          [0.000006, 0.000006, 0.000007, ..., 0.000008, 0.000009,
#           0.000009]],
#
#         ...,
#
#         [[0.000004, 0.000004, 0.000005, ..., 0.000006, 0.000006,
#           0.000006],
#          [0.000004, 0.000004, 0.000005, ..., 0.000006, 0.000006,
#           0.000006],
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000006, 0.000007,
#           0.000007],
#          [0.000005, 0.000005, 0.000005, ..., 0.000007, 0.000007,
#           0.000007],
#          ...,
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000008],
#          [0.000006, 0.000006, 0.000006, ..., 0.000008, 0.000008,
#           0.000009],
#          [0.000006, 0.000006, 0.000007, ..., 0.000008, 0.000009,
#           0.000009]],
#
#         ...,
#
#         [[0.000004, 0.000004, 0.000005, ..., 0.000006, 0.000006,
#           0.000006],
#          [0.000004, 0.000004, 0.000005, ..., 0.000006, 0.000006,
#           0.000006],
#          [0.000004, 0.000005, 0.000005, ..., 0.000006, 0.000006,
#           0.000007],
#          ...,
#          [0.000005, 0.000005, 0.000006, ..., 0.000007, 0.000007,
#           0.000008],
#          [0.000005, 0.000006, 0.000006, ..., 0.000007, 0.000008,
#           0.000008],
#          [0.000005, 0.000006, 0.000006, ..., 0.000007, 0.000008,
#           0.000008]],
#
#         [[0.000004, 0.000004, 0.000004, ..., 0.000006, 0.000006,
#           0.000006],
#          [0.000004, 0.000004, 0.000005, ..., 0.000006, 0.000006,
#           0.000006],
#          [0.000004, 0.000005, 0.000005, ..., 0.000006, 0.000006,
#           0.000007],
#          ...,
#          [0.000005, 0.000005, 0.000006, ..., 0.000007, 0.000007,
#           0.000008],
#          [0.000005, 0.000005, 0.000006, ..., 0.000007, 0.000008,
#           0.000008],
#          [0.000005, 0.000006, 0.000006, ..., 0.000007, 0.000008,
#           0.000008]],
#
#         [[0.000004, 0.000004, 0.000004, ..., 0.000006, 0.000006,
#           0.000006],
#          [0.000004, 0.000004, 0.000005, ..., 0.000006, 0.000006,
#           0.000006],
#          [0.000004, 0.000005, 0.000005, ..., 0.000006, 0.000006,
#           0.000007],
#          ...,
#          [0.000005, 0.000005, 0.000006, ..., 0.000007, 0.000007,
#           0.000008],
#          [0.000005, 0.000005, 0.000006, ..., 0.000007, 0.000007,
#           0.000008],
#          [0.000005, 0.000006, 0.000006, ..., 0.000007, 0.000008,
#           0.000008]]]])

# %%
def forwards(Pi, A, B, O):
    alpha = np.zeros([N, T])
    alpha[:, 0] = [Pi[i] * B[i][index(O[0])] for i in range(N)]
    for t in range(1, T):
        temp = np.array([B[i][index(O[t])] * np.dot(alpha[:, t-1], A[:, i]) for i in range(N)])
        print(f"B[0][index(O[t])]: {B[0][index(O[t])]}")
        print(f"alpha[:, t-1]: {alpha[:, t-1]}")
        print(f"A[:, 0]: {A[:, 0]}")
        print(f"alpha column at time {t}: {temp}")
        alpha[:, t] = temp
    return alpha

def backwards(Pi, A, B, O):
    beta = np.zeros([N, T])
    beta[:, T-1] = np.ones(N)
    for t in range(T-2, -1, -1):
        beta[:, t] = np.array([np.dot(np.multiply(beta[:, t+1], A[i, :]), B[(slice(0,N),)+index(O[t+1])]) for i in range(N)])
    return beta

# %%
def calculateGamma(alpha, beta):
    return np.array( [[alpha[i][t] * beta[i][t] / np.dot(alpha[:, t], beta[:, t]) for t in range(T)] for i in range(N)] )

def calculateXi(alpha, beta, A, B):
    return np.array( [np.array( [calculateXiAtIJ(alpha, beta, A, B, i, j) for j in range(N)] ) for i in range(N)] )

def calculateXiAtIJ(alpha, beta, A, B, i, j):
    return np.array( [alpha[i][t] * A[i][j] * beta[j][t+1] * B[j][index(O[t+1])] / doubleSum(alpha, beta, A, B, t) for t in range(T-1)] )

def doubleSum(alpha, beta, A, B, t):
    return np.dot(beta[:, t+1] * B[(slice(0,N),)+index(O[t+1])], np.array( [np.dot(alpha[:, t], A[:, l]) for l in range(N)] ))

# %%
def iterateA(gamma, xi):
    temp = np.array( [ [sum(xi[i, j, :]) / sum(gamma[i, :]) for j in range(N)] for i in range(N)] )
    return temp

def iterateB(gamma):
    return np.array(\
        [\
        np.array(\
            [ [ [sum([indicatorK(index(O[t]), (frac_change, frac_high, frac_low)) * gamma[i][t] for t in range(T)]) / sum(gamma[i, :])\
                for frac_low in range(10)]\
                for frac_high in range(10)]\
                for frac_change in range(50)]\
        )\
        for i in range(N)]\
        )

# %%
def BaumWelch(Pi, A, B, O, eps, maxIterations):
    alpha = forwards(Pi, A, B, O)
    beta = backwards(Pi, A, B, O)
    gamma = calculateGamma(alpha, beta)
    xi = calculateXi(alpha, beta, A, B)

    iteration = 1
    deltas = np.zeros(maxIterations)
    deltas[0] = np.inf
    while iteration < maxIterations and deltas[iteration-1] > eps:
        print(f"iteration: {iteration}")
        print(f"deltas: {deltas}")
        
        Pi_star = gamma[:, 0]
        A_star = iterateA(gamma, xi)
        B_star = iterateB(gamma)

        delta = max(np.linalg.norm(A_star - A), np.linalg.norm(B_star - B))
        Pi  = Pi_star
        A = A_star
        B = B_star

        alpha = forwards(Pi, A, B, O)
        beta = backwards(Pi, A, B, O)
        gamma = calculateGamma(alpha, beta)
        xi = calculateXi(alpha, beta, A, B)

        print(f"BM: {alpha}")
        print(f"BM: {beta}")

        iteration += 1
        deltas[iteration] = delta

    return (Pi_star, A_star, B_star)

# %%
def calculatePosterior(Pi, A, B, O_test):
    alpha = forwards(Pi, A, B, O_test)
    return sum(alpha[:, T-1])

def MAP(Pi, A, B, O_test):
    # O_new = guess for (d+1)-th day
    np.append(O_test, [0])
    best = 0
    best_posterior = -1
    # for guess in range(guesses):
    for frac_change in range(50):
        for frac_high in range(10):
            for frac_low in range(10):
                O_new = np.array([frac_change, frac_high, frac_low])
                O_test[-1] = O_new
                posterior = calculatePosterior(Pi, A, B, O_test)
                if posterior > best_posterior:
                    best = O_new
                    best_posterior = posterior

    return (best, best_posterior)

# %%
HMM = BaumWelch(Pi, A, B, O, 1e-4, 2000)
# Out:
# B[0][index(O[t])]: 6.9384299810273665e-06
# alpha[:, t-1]: [0.000002 0.000002 0.000002 0.000002]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 1: [0. 0. 0. 0.]
# B[0][index(O[t])]: 7.429618418224626e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 2: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.81679845845037e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 3: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.467312013117099e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 4: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.897035459765814e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 5: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.581822712890687e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 6: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.599563443036378e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 7: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.637430434147874e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 8: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.567878303529373e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 9: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.825078720038556e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 10: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.8403737889199896e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 11: [0. 0. 0. 0.]
# B[0][index(O[t])]: 7.760304916728424e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 12: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6
[0. 0. 0. 0.]
# B[0][index(O[t])]: 6.494258235464193e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 136: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.982897589218399e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 137: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.99713861534939e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 138: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.539940210644311e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 139: [0. 0. 0. 0.]
# B[0][index(O[t])]: 7.153698037193361e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 140: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.766156138390406e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 141: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.5259470122537104e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 142: [0. 0. 0. 0.]
# B[0][index(O[t])]: 7.0821456506909135e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 143: [0. 0. 0. 0.]
# B[0][index(O[t])]: 7.444327288236797e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 144: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.925733708770054e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 145: [0. 0. 0. 0.]
# B[0][index(O[t])]: 7.039737758373773e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 146: [0. 0. 0. 0.]
# B[0][index(O[t])]: 7.1976308267299435e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 147: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.667943186397993e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 148: [0. 0. 0. 0.]
# B[0][index(O[t])]: 6.599563443036378e-06
# alpha[:, t-1]: [0. 0. 0. 0.]
# A[:, 0]: [0.25 0.25 0.25 0.25]
# alpha column at time 149: [0. 0. 0. 0.]
# iteration: 1
# deltas: [inf  0.  0. ...  0.  0.  0.]
# /var/folders/gd/27_ffn191334fg1hsfv36td80000gn/T/ipykernel_4165/1236208302.py:2: RuntimeWarning: invalid value encountered in scalar divide
#   return np.array( [[alpha[i][t] * beta[i][t] / np.dot(alpha[:, t], beta[:, t]) for t in range(T)] for i in range(N)] )
# /var/folders/gd/27_ffn191334fg1hsfv36td80000gn/T/ipykernel_4165/1236208302.py:8: RuntimeWarning: invalid value encountered in scalar divide
#   return np.array( [alpha[i][t] * A[i][j] * beta[j][t+1] * B[j][index(O[t+1])] / doubleSum(alpha, beta, A, B, t) for t in range(T-1)] )
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 1: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 2: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 3: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 4: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 5: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 6: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 7: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 8: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 9: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 10: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 11: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 12: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 13: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 14: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 15: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 16: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 17: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 18: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 19: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 20: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 21: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 22: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 23: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 24: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 25: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 26: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 27: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 28: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 29: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 30: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 31: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 32: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 33: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 34: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 35: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 36: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 37: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 38: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 39: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 40: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 41: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 42: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 43: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 44: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 45: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 46: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 47: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 48: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 49: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 50: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 51: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 52: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 53: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 54: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 55: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 56: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 57: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 58: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 59: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 60: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 61: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 62: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 63: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 64: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 65: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 66: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 67: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 68: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 69: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 70: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 71: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 72: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 73: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 74: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 75: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 76: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 77: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 78: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 79: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 80: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 81: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 82: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 83: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 84: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 85: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 86: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 87: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 88: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 89: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 90: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 91: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 92: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 93: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 94: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 95: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 96: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 97: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 98: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 99: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 100: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 101: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 102: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 103: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 104: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 105: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 106: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 107: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 108: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 109: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 110: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 111: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 112: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 113: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 114: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 115: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 116: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 117: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 118: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 119: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 120: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 121: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 122: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 123: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 124: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 125: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 126: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 127: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 128: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 129: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 130: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 131: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 132: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 133: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 134: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 135: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 136: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 137: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 138: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 139: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 140: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 141: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 142: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 143: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 144: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 145: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 146: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 147: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 148: [nan nan nan nan]
# B[0][index(O[t])]: nan
# alpha[:, t-1]: [nan nan nan nan]
# A[:, 0]: [nan nan nan nan]
# alpha column at time 149: [nan nan nan nan]
# BM: [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan]]
# BM: [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan  1.]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan  1.]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan  1.]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan  1.]]

# %%
V = np.array([[0,1], [1,2]])
V[:, 0] = [3, 4]

# %%
V
# Out:
# array([[3, 1],
#        [4, 2]])

# %%
T
# Out:
# 365

# %%
B[0][index(O[0])] * 25
# Out:
# 1.4323404257549819

# %%
alpha[:, 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[266], line 1
# ----> 1 alpha[:, 0]
#
# NameError: name 'alpha' is not defined
